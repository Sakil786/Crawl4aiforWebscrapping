# %%
# %%capture
# !pip install "crawl4ai @ git+https://github.com/unclecode/crawl4ai.git" pydantic

# %%
import time, os, sys
import json
from crawl4ai.chunking_strategy import *
from crawl4ai.extraction_strategy import *
from crawl4ai.crawler_strategy import *
from crawl4ai.web_crawler import WebCrawler
from crawl4ai import config
crawler = WebCrawler()
crawler.warmup()
# Out:
# [LOG] 🚀 Initializing LocalSeleniumCrawlerStrategy
# [LOG] 🌤️  Warming up the WebCrawler
# [LOG] 🌞 WebCrawler is ready to crawl

# %%
from google.colab import userdata
os.environ['groq_api_key'] = userdata.get('groq_api_key')

# %%
# from pydantic import BaseModel, Field

# class PageSummary(BaseModel):
#     title: str = Field(..., description="Title of the page.")
#     summary: str = Field(..., description="Summary of the page.")
#     brief_summary: str = Field(..., description="Brief summary of the page.")
#     keywords: list = Field(..., description="Keywords assigned to the page.")

# url = r'https://marketplace.visualstudio.com/items?itemName=Unclecode.groqopilot'
# result = crawler.run(
#     url=url,
#     word_count_threshold=1,
#     extraction_strategy= LLMExtractionStrategy(
#         # provider= "openai/gpt-4o-mini", api_token = os.getenv('OPENAI_API_KEY'),
#         provider= "groq/llama-3.1-70b-versatile", api_token = os.getenv('groq_api_key'),
#         schema=PageSummary.model_json_schema(),
#         extraction_type="schema",
#         apply_chunking =False,
#         instruction="From the crawled content, extract the following details: "\
#             "1. Title of the page "\
#             "2. Summary of the page, which is a detailed summary "\
#             "3. Brief summary of the page, which is a paragraph text "\
#             "4. Keywords assigned to the page, which is a list of keywords. "\
#             'The extracted JSON format should look like this: '\
#             '{ "title": "Page Title", "summary": "Detailed summary of the page.", "brief_summary": "Brief summary in a paragraph.", "keywords": ["keyword1", "keyword2", "keyword3"] }'
#     ),
#     bypass_cache=True,
# )

# page_summary = json.loads(result.extracted_content)

# print(json.dumps(page_summary, indent = 4))

# %%
from pydantic import BaseModel, Field

class OpenAIModelFee(BaseModel):
    model_name: str = Field(..., description="Name of the OpenAI model.")
    input_fee: str = Field(..., description="Fee for input token for the OpenAI model.")
    output_fee: str = Field(..., description="Fee for output token ßfor the OpenAI model.")

url = r'https://openai.com/api/pricing/'
result = crawler.run(
    url=url,
    word_count_threshold=1,
    extraction_strategy= LLMExtractionStrategy(
        # provider= "openai/gpt-4o-mini", api_token = os.getenv('OPENAI_API_KEY'),
        provider= "groq/llama-3.1-70b-versatile", api_token = os.getenv('groq_api_key'),
        schema=OpenAIModelFee.schema(),
        extraction_type="schema",
        instruction="""From the crawled content, extract all mentioned model names along with their fees for input and output tokens.
        Do not miss any models in the entire content. One extracted model JSON format should look like this:
        {"model_name": "GPT-4", "input_fee": "US$10.00 / 1M tokens", "output_fee": "US$30.00 / 1M tokens"}.Think step by step and perform the task."""
    ),
    bypass_cache=True,
)
print(json.dumps(json.loads(result.extracted_content)[:10], indent = 4))
# Out:
# [LOG] 🚀 Crawling done for https://openai.com/api/pricing/, success: True, time taken: 2.209665060043335 seconds
# [LOG] 🚀 Content extracted for https://openai.com/api/pricing/, success: True, time taken: 0.10495996475219727 seconds
# [LOG] 🔥 Extracting semantic blocks for https://openai.com/api/pricing/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 0
# [LOG] Extracted 10 blocks from URL: https://openai.com/api/pricing/ block index: 0
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 1
# [LOG] Extracted 8 blocks from URL: https://openai.com/api/pricing/ block index: 1
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 2
# [LOG] Extracted 24 blocks from URL: https://openai.com/api/pricing/ block index: 2
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 3
# [LOG] Extracted 7 blocks from URL: https://openai.com/api/pricing/ block index: 3
# ...

# %%
from pydantic import BaseModel, Field
import pandas as pd
class OpenAIModelFee(BaseModel):
    model_name: str = Field(..., description="Name of the OpenAI model.")
    input_fee: str = Field(..., description="Fee for input token for the OpenAI model.")
    output_fee: str = Field(..., description="Fee for output token ßfor the OpenAI model.")

url = r'https://openai.com/api/pricing/'
result = crawler.run(
    url=url,
    word_count_threshold=1,
    extraction_strategy= LLMExtractionStrategy(
        # provider= "openai/gpt-4o-mini", api_token = os.getenv('OPENAI_API_KEY'),
        provider= "groq/llama-3.1-70b-versatile", api_token = os.getenv('groq_api_key'),
        schema=OpenAIModelFee.schema(),
        extraction_type="schema",
        instruction="""From the crawled content, extract all mentioned model names along with their fees for input and output tokens.
        Do not miss any models in the entire content. One extracted model JSON format should look like this:
        {"model_name": "GPT-4", "input_fee": "US$10.00 / 1M tokens", "output_fee": "US$30.00 / 1M tokens"}.Think step by step and perform the task."""
    ),
    bypass_cache=True,
)
final_result=json.dumps(json.loads(result.extracted_content)[:10], indent = 4)
dataframe=pd.read_json(final_result)
# Out:
# [LOG] 🚀 Crawling done for https://openai.com/api/pricing/, success: True, time taken: 0.27814459800720215 seconds
# [LOG] 🚀 Content extracted for https://openai.com/api/pricing/, success: True, time taken: 0.002283334732055664 seconds
# [LOG] 🔥 Extracting semantic blocks for https://openai.com/api/pricing/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 0
# [LOG] Extracted 0 blocks from URL: https://openai.com/api/pricing/ block index: 0
# [LOG] 🚀 Extraction done for https://openai.com/api/pricing/, time taken: 1.2450296878814697 seconds.
# <ipython-input-24-b5760519c295>:24: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dataframe=pd.read_json(final_result)
# Empty DataFrame
# Columns: []
# Index: []

# %%
dataframe.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# <ipython-input-13-6587d1e3341a>:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dataframe=pd.read_json(final_result)
#           model_name                input_fee                 output_fee  \
# 0             gpt-4o  $5.00 / 1M input tokens  $15.00 / 1M output tokens
# 1             gpt-4o  $2.50 / 1M input tokens   $7.50 / 1M output tokens
# 2  gpt-4o-2024-08-06  $2.50 / 1M input tokens  $10.00 / 1M output tokens
# 3  gpt-4o-2024-08-06  $1.25 / 1M input tokens   $5.00 / 1M output tokens
# 4  gpt-4o-2024-05-13  $5.00 / 1M input tokens  $15.00 / 1M output tokens
#
#    error
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
dataframe.drop(columns=['error'],inplace=True)

# %%
dataframe
# Out:
#                model_name                 input_fee                 output_fee
# 0                  gpt-4o   $5.00 / 1M input tokens  $15.00 / 1M output tokens
# 1                  gpt-4o   $2.50 / 1M input tokens   $7.50 / 1M output tokens
# 2       gpt-4o-2024-08-06   $2.50 / 1M input tokens  $10.00 / 1M output tokens
# 3       gpt-4o-2024-08-06   $1.25 / 1M input tokens   $5.00 / 1M output tokens
# 4       gpt-4o-2024-05-13   $5.00 / 1M input tokens  $15.00 / 1M output tokens
# 5       gpt-4o-2024-05-13   $2.50 / 1M input tokens   $7.50 / 1M output tokens
# 6             gpt-4o mini  $0.150 / 1M input tokens  $0.600 / 1M output tokens
# 7             gpt-4o mini  $0.075 / 1M input tokens  $0.300 / 1M output tokens
# 8  gpt-4o-mini-2024-07-18  $0.150 / 1M input tokens  $0.600 / 1M output tokens
# 9  gpt-4o-mini-2024-07-18  $0.075 / 1M input tokens  $0.300 / 1M output tokens

# %%
from pydantic import BaseModel, Field
import pandas as pd
import json

class OpenAIModelFee(BaseModel):
    model_name: str = Field(..., description="Name of the OpenAI model.")
    input_fee: str = Field(..., description="Fee for input token for the OpenAI model.")
    output_fee: str = Field(..., description="Fee for output token for the OpenAI model.")

def fetch_model_fees(url: str, provider: str, api_token: str) -> pd.DataFrame:
    # Crawler and extraction strategy
    result = crawler.run(
        url=url,
        word_count_threshold=1,
        extraction_strategy=LLMExtractionStrategy(
            provider=provider,
            api_token=api_token,
            schema=OpenAIModelFee.schema(),
            extraction_type="schema",
            instruction="""From the crawled content, extract all mentioned model names along with their fees for input and output tokens.
            Do not miss any models in the entire content. One extracted model JSON format should look like this:
            {"model_name": "GPT-4", "input_fee": "US$10.00 / 1M tokens", "output_fee": "US$30.00 / 1M tokens"}.
            Think step by step and perform the task."""
        ),
        bypass_cache=True,
    )

    # Extracting all results from the extracted content
    final_result = json.dumps(json.loads(result.extracted_content), indent=4)

    # Loading into pandas DataFrame
    dataframe = pd.read_json(final_result)
    return dataframe

# Example usage:
url = r'https://openai.com/api/pricing/'
provider = "groq/llama-3.1-70b-versatile"
api_token = os.getenv('groq_api_key')
df = fetch_model_fees(url, provider, api_token)
print(df.head())
# Out:
# [LOG] 🚀 Crawling done for https://openai.com/api/pricing/, success: True, time taken: 0.38724207878112793 seconds
# [LOG] 🚀 Content extracted for https://openai.com/api/pricing/, success: True, time taken: 0.00690460205078125 seconds
# [LOG] 🔥 Extracting semantic blocks for https://openai.com/api/pricing/, Strategy: LLMExtractionStrategy
# [LOG] Call LLM for https://openai.com/api/pricing/ - block index: 0
# [LOG] Extracted 0 blocks from URL: https://openai.com/api/pricing/ block index: 0
# [LOG] 🚀 Extraction done for https://openai.com/api/pricing/, time taken: 1.1564249992370605 seconds.
# Empty DataFrame
# Columns: []
# Index: []
# <ipython-input-23-be04e7225e1b>:32: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dataframe = pd.read_json(final_result)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
